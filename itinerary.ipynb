# %%
import os
import numpy as np
import pandas as pd
from pprint import pprint

def open_dataset(file_name):
    return pd.read_csv(filepath_or_buffer=file_name, delimiter="\t", encoding="utf-8", header=0)

itineraries = open_dataset('data_sncf/timetables.csv')
# itineraries = open_dataset('data_sncf/test.csv')
itineraries = itineraries.sort_values(by=['trip_id', 'trajet', 'duree'], ascending=[True, True, True])

# dataframe refacto 
trajet_splited = itineraries['trajet'].str.split(' - ')

itineraries['start'] = trajet_splited.str[0]
itineraries['end'] = trajet_splited.str[1]

itineraries.drop('trajet', axis=1, inplace=True)

itineraries
# Out:
#                      trip_id  duree                    start  \
# 0      OCESN003100F140147152    138         Gare de Le Havre
# 1      OCESN003190F040047309    145           Gare de Dieppe
# 2      OCESN003198F030037315     97  Gare de Paris-St-Lazare
# 3      OCESN003300F030037323    194        Gare de Cherbourg
# 4      OCESN003313F380387526    149             Gare de Caen
# ...                      ...    ...                      ...
# 1570  OCESN895822F0500552575    244    Gare de Belfort-Ville
# 1571  OCESN895830F0200252600    103  Gare de Lons-le-Saunier
# 1572  OCESN895880F0500552634    144    Gare de Belfort-Ville
# 1573  OCESN895940F0200252654     89  Gare de Besançon-Viotte
# 1574  OCESN895942F0900952655     81  Gare de Bourg-en-Bresse
#
#                             end
# 0       Gare de Paris-St-Lazare
# 1       Gare de Paris-St-Lazare
# 2     Gare de Rouen-Rive-Droite
# 3       Gare de Paris-St-Lazare
# 4       Gare de Paris-St-Lazare
# ...                         ...
# 1570      Gare de Lyon-Perrache
# 1571      Gare de Lyon-Perrache
# 1572    Gare de Lons-le-Saunier
# 1573    Gare de Lons-le-Saunier
# 1574           Gare de Mouchard
#
# [1575 rows x 4 columns]

# %%
# try to find a travel from id
findTravel = itineraries.loc[itineraries['trip_id'] == "OCESN014033F0900915597"]
print(findTravel)
# Out:
#                    trip_id  duree            start            end
# 19  OCESN014033F0900915597     72  Gare de Orléans  Gare de Tours

# %%
# Filter all possible localisations
locsStart = itineraries['start'].tolist()
locsEnd = itineraries['end'].tolist()
locs = list(dict.fromkeys(locsStart + locsEnd))
# len(locs)
locs
# Out:
# ['Gare de Le Havre',
#  'Gare de Dieppe',
#  'Gare de Paris-St-Lazare',
#  'Gare de Cherbourg',
#  'Gare de Caen',
#  'Gare de Granville',
#  'Gare de Dreux',
#  'Gare de Bourges',
#  'Gare de Paris-Austerlitz',
#  'Gare de Nevers',
#  'Gare de Argentan',
#  'Gare de Orléans',
#  'Gare de Aubrais-(les)',
#  'Gare de Paris-Bercy',
#  'Gare de Calais Ville',
#  'Gare de Boulogne Ville',
#  'Gare de Amiens',
#  'Gare de Cambrai Ville',
#  'Gare de Maubeuge',
#  'Gare de Paris Gare du Nord',
#  'Gare de Compiègne',
#  'Gare de Le Mans',
#  'Gare de Nogent-le-Rotrou',
#  'Gare de Chartres',
#  'Gare de Blois-Chambord',
#  'Gare de Lyon-Perrache',
#  'Gare de Latour-de-Carol-Enveitg',
#  'Gare de Font-Romeu-Odeillo-Via',
#  'Gare de Briançon',
#  'Gare de Romans-Bourg-de-Péage',
#  'Gare de Gap',
#  'Gare de Aix-en-Provence',
#  'Gare de Marseille-St-Charles',
#  'Gare de Les Arcs-Draguignan',
#  'Gare de Grenoble',
#  'Gare de Chambéry-Chal.-les-Eaux',
#  'Gare de Annecy',
#  'Gare de Avignon-Centre',
#  'Gare de Lyon-Part-Dieu',
#  'Gare de Dijon-Ville',
#  'Gare de Mâcon-Ville',
#  'Gare de Bourg-St-Maurice',
#  'Gare de Albertville',
#  'Gare de Bourgoin-Jallieu',
#  'Gare de La Chaux-de-Fonds',
#  'Gare de Besançon-Viotte',
#  'Gare de Besançon-Mouillère',
#  'Gare de Pontarlier',
#  'Gare de Frasne',
#  'Gare de Neuchâtel',
#  'Gare de Dole-Ville',
#  'Gare de Delémont',
#  'Gare de Delle',
#  'Gare de Biel',
#  'Gare de Aix-les-Bains-le-Revard',
#  'Gare de St-Gervais-L-B-Le-Fayet',
#  'Gare de Chamonix-Mont-Blanc',
#  'Gare de Aulnoye Aymeries',
#  'Gare de Courtrai/Kortrijk',
#  'Gare de Lille Flandres',
#  'Gare de Brive-la-Gaillarde',
#  'Gare de Le Creusot',
#  'Gare de Nice-Ville',
#  'Gare de Breil-sur-Roya',
#  'Gare de Annemasse',
#  'Gare de Decize',
#  'Gare de Coppet',
#  'Gare de Cluses (Hte-Savoie)',
#  'Gare de Forbach',
#  'Gare de Bening',
#  'Bitche',
#  'Bitche-Camp',
#  'Gare de Haguenau',
#  'Bouxwiller-Schattenmann',
#  'Gare de Saverne',
#  'Gare de Ingwiller',
#  'Dossenheim-(Mairie)',
#  'Gare de Obermodern',
#  'Bouxwiller-Babenhausen',
#  'Gare de Strasbourg',
#  'Gare de Benfeld',
#  'Gare de Colmar',
#  'Buswiller-Eglise',
#  "Ettendorf-Pl,-de-L'ecol",
#  'Ettendorf-(Angle-Pont)',
#  'Gare de Diemeringen',
#  'Gare de Sarreguemines',
#  'Gare de Lutzelbourg',
#  'Gare de Kruth',
#  'Gare de Cernay (Haut-Rhin)',
#  'Cernay-(Lycée)',
#  'Gare de Basel-SBB',
#  'Frohmuhl- (Lavoir)',
#  'Hattmatt-S.-Polyvalente',
#  'Gare de Herrlisheim (Bas-Rhin)',
#  'Gare de Lauterbourg',
#  'Gare de Entzheim-Aéroport',
#  'Gare de Barr',
#  'Gare de Molsheim',
#  'Gare de Rothau',
#  'Gare de Saales',
#  'Gare de Altkirch',
#  'Gare de Belfort-Ville',
#  'Gare de Sélestat',
#  'Gare de St-Dié-des-Vosges',
#  'Ste-Croix/Mines-Sq-de-G',
#  'Ste-Marie-/-Mines-Maire',
#  'Liepvre-(-R.-GUTH-)',
#  'Ste-Marie-/-Ms-Pl-.CdG',
#  'Gare de Montluçon-Ville',
#  'Laqueuille',
#  'Gare de Clermont-Ferrand',
#  'Gare de Gannat',
#  'Gare de Aurillac',
#  'Gare de Thiers',
#  'Gare de Arvant',
#  'Gare de Moulins-sur-Allier',
#  'Ancizes-St-Georges-Bour',
#  'Gare de Lapeyrouse(Puy-de-Dôme)',
#  'Gare de Volvic',
#  'Gare de Massiac-Blesle',
#  'Gare de Riom-Châtel-Guyon',
#  'Gare de Neussargues',
#  "Gare de St-Chély-d'Apcher",
#  'Brioude-Lycée-Lafayette',
#  'Gare de Langeac',
#  'Gare de Brioude',
#  'Gare de Le Puy-en-Velay',
#  'Ambert',
#  'Gare de Pont-de-Dore',
#  'Gare de Ussel',
#  'Gare de Vic-le-Comte',
#  'Gare de Issoire',
#  'Gare de Luzy(Nièvre)',
#  'Gare de Cercy-la-Tour',
#  'Gare de Autun',
#  'Chauffailles-Gambetta',
#  'Gare de Digoin',
#  'Gare de Louhans',
#  'Gare de Bourg-en-Bresse',
#  'Gare de Auxerre-St-Gervais',
#  'Gare de Clamecy',
#  'Gare de Lorient',
#  'Châteaubriant',
#  'Gare de Dinan',
#  'Gare de Valençay',
#  'Gare de Romorantin-Blanc-Argent',
#  "Gare de Faubourg-d'Orléans",
#  'La Ferté-sur-Chiers',
#  'Gare de Châlons-en-Champagne',
#  'Gare de St-Dizier',
#  'Gare de Joinville',
#  'Gare de Chaumont',
#  'Gare de Bar-sur-Aube',
#  'Gare de Troyes',
#  'Bayel-Eglise',
#  'Gare de Vendeuvre (Aube)',
#  'Bricon(la Poste)',
#  'Gare de St-Florentin-Vergigny',
#  'Gare de Laroche-Migennes',
#  'Gare de Romilly-sur-Seine',
#  'Gare de Nogent-sur-Seine',
#  'Gare de Charleville-Mézières',
#  'Gare de Fismes',
#  'Gare de Aillevillers',
#  'Gare de Le Locle',
#  'Gare de Le Valdahon',
#  'Gare de Lons-le-Saunier',
#  'Gare de Mouchard',
#  'Dompierre-Halte-Rout.',
#  'Gare de Champagnole',
#  'Gare de Champagnole-PE-Victor',
#  'Gare de Andelot',
#  'Gare de Alès',
#  'Gare de La Bastide-St-Laurent',
#  'Gare de Langogne',
#  'Gare de Millau',
#  'Gare de Mende',
#  'Gare de Carcassonne',
#  'Gare de Limoux',
#  'Gare de Bédarieux',
#  'Gare de Guéret',
#  'Gare de Tulle',
#  'Gare de Egletons',
#  'Bort-les-Orgues',
#  'Gare de Nancy-Ville',
#  'Martigny-les-B-Thiebaut',
#  'Damblain Eglise',
#  'Gare de Contrexéville',
#  'Gare de Vittel',
#  'Bitche-Quartier-Driant',
#  'Gare de Charmes (Vosges)',
#  'Igney (Centre)',
#  'Gare de Sarrebourg',
#  'Gare de Longuyon',
#  'Gare de Morhange',
#  'Longuyon (Collège)',
#  'Fénétrange (Gendarm.)',
#  'Loudrefing',
#  'Sarrebourg (Place Math)',
#  'Sarrebourg-LP-Messmer',
#  'Gare de Neufchâteau',
#  'Gare de Toul',
#  'Allamps-Esat',
#  'Creutzwald G.R.',
#  'Gare de Epinal',
#  'Bruyères (Vosges)',
#  'Bouzonville',
#  'Gare de Thionville',
#  'Corcieux Le Conti',
#  'Gare de Arches',
#  'Bruyères Chanzy Gare',
#  'Herbitzheim R. Hambach',
#  'Herbitzheim Mairie',
#  'Berthelming-Mairie',
#  'Gare de Metz-Ville',
#  'Keskastel',
#  'Gare de Bar-le-Duc',
#  'Gare de Conflans-Jarny',
#  'Gare de Figeac',
#  'Gare de Mazamet',
#  'Gare de Muret',
#  'Gare de Pau',
#  'Gare de Agen',
#  'Gare de Longages-Noé',
#  'Gare de Montréjeau-Gourdan-Pol.',
#  'Gare de Ax-les-Thermes',
#  'Gare de Foix',
#  'Gare de Souillac',
#  'Gare de Albi-Ville',
#  'Comines (France)',
#  'Gare de Abbeville',
#  'Gare de Lens',
#  'Gare de Avesnes',
#  'Gare de Arras',
#  'Gare de Hazebrouck',
#  'Gare de Busigny',
#  'Gare de Calais Fréthun',
#  'Gare de Coutances',
#  'Bagnoles- Orne Egl.Mad.',
#  'Gare de Alençon',
#  "Gare de L'Aigle",
#  'Gare de Lisieux',
#  'Gare de Dives-Cabourg',
#  'Gare de Evreux',
#  'Gare de Villedieu (Gare)',
#  'Gare de Bréauté-Beuzeville',
#  'Gare de Mantes-la-Jolie',
#  'Pont-Audemer-Gare-SNCF',
#  'Rouen-Gare-Routière',
#  'Bourg-Achard Champ de F',
#  'Gare de Nantes',
#  'Gare de Cholet',
#  'Gare de Albert',
#  'Gare de Beauvais-Gare-SNCF',
#  'Gare de Hirson',
#  'Gare de Chatellerault',
#  'Gare de Mauzé',
#  'Gare de Niort',
#  'Gare de Bressuire',
#  'Gare de La Roche-sur-Yon',
#  'Gare de Valence-TGV',
#  'Grenoble-Gare-Routière',
#  'Gare de St-André-le-Gaz',
#  'Lyon-Part-Dieu-Gare-Rou',
#  'Gare de Lozanne',
#  'Gare de Lamure-sur-Azergues',
#  "Bois-d'Oingt-Centre",
#  'Gare de Die',
#  'Gare de Veynes-Dévoluy',
#  'Gare de Luc-en-Diois',
#  'Gare de Evian-les-Bains',
#  'Saint-Etienne-Chtx GR',
#  'Gare de Modane',
#  'Annonay-Gare-Route',
#  'Privas-Cours-du-Palais',
#  'Gare de Moûtiers-Salins-Brides',
#  'Gare de Bonneville',
#  'Aubenas-Pl.-de-la-Paix',
#  'Bourg-en-Bresse Gare R',
#  'Gare de Oyonnax',
#  'Chamberry-Jacob',
#  'Montélimar-G-Routière',
#  'Gare de Saint-Claude',
#  'Gare de Thonon-les-Bains',
#  'Gare de Franois',
#  'Gare de Auxonne',
#  'Gare de Bellegarde-s-V. Gare',
#  'Gare de Ambérieu-en-Bugey',
#  'Gare de Boën',
#  'Gare de Montbrison',
#  'Noirétable',
#  'Gare de Clelles-Mens',
#  'Clelles-Mairie',
#  'Gare de Vif',
#  'Gare de Sain-Bel',
#  'Lyon-Perrache-Gare-Rout',
#  'Argentine',
#  'Gare de St-Priest',
#  'Gare de Villefranche-sur-Saône',
#  'Gare de La Tour-du-Pin',
#  'Gare de Feurs',
#  'Gare de Albens',
#  'Gare de Sérézin',
#  'Communay-Stade',
#  'Gare de Epierre-St-Léger',
#  'Gare de St-Jean-de-Maurienne-A.',
#  'Aiton-Salle-Polyvalente',
#  'Gare de Chinon',
#  'Chinon-Lycée-Rabelais',
#  'Gare de Tours',
#  'Gare de Château-du-Loir',
#  'Droué (Centre)',
#  'Courtalain-Centre',
#  'Chartres-Gare-Routière',
#  'Gare de Brou',
#  'Gare de Vendôme',
#  'Aubigny-sur-Nere-Mail',
#  'Gare de Gien',
#  'Gare de Cosne-sur-Loire',
#  'Bourges-Gare-Routière',
#  'Châteauroux Gare Rout.',
#  'Gare de Vierzon',
#  'Gare de Issoudun',
#  'Le-Blanc-Pl-du-Bateau',
#  'Gare de Nouan-le-Fuzelier',
#  'Chaumont-sur-Tharonne',
#  'Gare de Lamotte-Beuvron',
#  'Châteauroux-Ly-B-Pascal',
#  'Châteauroux-Lycée-Agric',
#  'Gare de Thesee',
#  'Romorantin-BA-G.R.',
#  'Gare de Loches',
#  'Buzançais',
#  'Chatillon-Mail',
#  'Clion-sur-Indre',
#  'Gare de Cormery',
#  'Chambourg-Chopin',
#  'Loches-Lycee-St-Denis',
#  'Gare de Esvres',
#  'Gare de La Douzillère',
#  'Loches-LEP',
#  'Gare de Châteaudun',
#  'Châteaudun-LEP-Paulsen',
#  'Gare de Château-Renault',
#  'Gare de Lunéville',
#  'Luneville-LP',
#  'Lunéville (Cité Scolai)',
#  'Gare de Remiremont',
#  'Gare de Longwy',
#  'Bussang (Gare SNCF)',
#  'Bresse-Claudel (la)',
#  'Gare de Audun-le-Roman',
#  'Gare de Marle-sur-Serre',
#  'BarentonÂ\xa0Cel',
#  'Barenton-sur-Serre',
#  'Gare de Neustadt (Weinstr) Hbf',
#  'Gare de WINDEN PFALZ',
#  'Gare de Landau-Pfalz-Hbf',
#  'Gare de Fougères',
#  'Gare de Grasse',
#  'Gare de Menton',
#  'Gare de Cannes-la-Bocca',
#  'Gare de Monaco-Monte-Carlo',
#  'Gare de Cannes',
#  'Gare de Saarbrücken /Sarrebruck',
#  'Gare de Mommenheim',
#  'Gare de Luxembourg',
#  'Gare de Perpignan',
#  'Gare de Narbonne',
#  'Gare de Nîmes',
#  'Gare de Port-Bou',
#  'Gare de Montpellier-Saint-Roch',
#  'Gare de Offenburg',
#  'Gare de Kehl',
#  'Gare de Mulhouse',
#  'Gare de Freiburg-Breisgau',
#  'Gare de Bettembourg',
#  'Gare de Genève',
#  'Gare de St-Pierre-des-Corps',
#  'Gare de Roeschwoog',
#  'Gare de Thann-Saint-Jacques',
#  'Gare de Erstein',
#  'Gare de Bayonne',
#  'Gare de Mont-de-Marsan',
#  'Gare de Bordeaux-St-Jean',
#  'Gare de Lesparre',
#  'Gare de Dax',
#  'Gare de Arcachon',
#  'Gare de Condat-le-Lardin',
#  'Gare de Bedous',
#  'Gare de Oloron-Ste-Marie',
#  'Gare de Bidos',
#  'Gare de Bergerac',
#  'Gare de Libourne',
#  'Gare de Commentry',
#  'Gare de Firminy',
#  'Gare de Dijon-Porte-Neuve',
#  'Gare de Avallon',
#  'Gare de Chagny',
#  'Gare de Besançon-Franche-Comté',
#  'Gare de Rennes',
#  'Gare de Montauban-de-Bretagne',
#  'Gare de Messac-Guipry',
#  'Gare de Redon',
#  'Gare de Beslé',
#  'Gare de Brest',
#  'Gare de Landerneau',
#  'Gare de Lannion',
#  'Gare de Guingamp',
#  'Gare de Carhaix',
#  'Gare de Port-de-Piles',
#  'Gare de Châteauroux',
#  'Gare de Argenton-sur-Creuse',
#  'Gare de Port-Boulet',
#  'Gare de Reims',
#  'Gare de Rethel',
#  'Gare de Laon',
#  'Gare de Dormans',
#  'Gare de Culmont-Chalindrey',
#  'Gare de Cerbère',
#  'Gare de Le Grau-du-Roi',
#  'Gare de Castelnaudary',
#  'Gare de Marvejols',
#  'Gare de Le Dorat',
#  'Gare de Limoges-Bénédictins',
#  'Gare de St-Yrieix-la-Perche',
#  'Gare de Nexon',
#  'Gare de Objat',
#  'Gare de Baroncourt',
#  'Gare de Hagondange',
#  'Gare de Liverdun',
#  'Gare de Castres',
#  'Gare de Capdenac',
#  'Gare de Auch',
#  "Gare de L'Isle-Jourdain (Gers)",
#  'Gare de Colomiers',
#  'Gare de Cahors',
#  'Gare de Boussens',
#  'Gare de Lourdes',
#  'Gare de Douai',
#  'Gare de Jeumont',
#  'Gare de Charleroi Sud',
#  'Gare de Dunkerque',
#  'Gare de Angers-St-Laud',
#  'Gare de Connerré-Beillé',
#  'Gare de Laval',
#  'Gare de Tergnier',
#  'Gare de Creil',
#  'Gare de St Quentin',
#  'Gare de Abancourt',
#  'Gare de Angoulême',
#  'Gare de La Rochelle-Ville',
#  'Gare de La-Rochelle-Pt-Dauphine',
#  'Aix-Gare-Routière',
#  'Roanne-Gare-Routière',
#  'Gare de La Roche-sur-Foron',
#  'Gare de Chedde',
#  'Gare de Krimmeri-Meinau',
#  'Gare de Obernai',
#  'Gare de Lutterbach Tram-train',
#  'Gare de Mulhouse-Gare-Centrale',
#  'Gare de Niederbronn',
#  'Gare de Epernay',
#  'Gare de Paris-Est',
#  'Gare de Champagne-Ardenne',
#  'Gare de Château-Thierry',
#  'Gare de Longueville (S.-et-M.)',
#  'Gare de Béthune',
#  'Gare de Lille Europe',
#  "Gare de Clermont-de-l'Oise",
#  'Gare de Crépy-en-Valois',
#  'Gare de Oissel',
#  'Gare de Fécamp',
#  'Gare de Elbeuf-St-Aubin',
#  'Gare de Rouen-Rive-Droite',
#  'Gare de Bueil',
#  'Gare de Dol',
#  'Gare de Janzé',
#  'Gare de Montreuil-sur-Ille',
#  'Gare de Callac',
#  'Gare de La Brohinière',
#  'Gare de Quimper',
#  'Gare de Le Croisic',
#  "Gare de Les Sables-d'Olonne",
#  'Gare de Chantonnay',
#  'Gare de Ancenis',
#  'Gare de Châteaubriant-TT',
#  'Gare de Clisson',
#  'Gare de Saumur',
#  'Gare de Thouars',
#  'Gare de Reignac',
#  'Gare de Paris-Gare-de-Lyon',
#  'Gare de Bléré-la-Croix',
#  'Gare de St-Aignan-Noyers',
#  'Gare de Salbris',
#  'Gare de Poitiers',
#  'Gare de Royan',
#  'Gare de Mussidan',
#  'Gare de Le Buisson',
#  'Gare de Monsempron-Libos',
#  'Gare de Macau',
#  'Gare de Biganos-Facture',
#  'Gare de Eymoutiers-Vassiviere',
#  'Gare de Felletin-Gare',
#  'Gare de Périgueux',
#  'Gare de La Souterraine',
#  'Gare de Rodez',
#  'Gare de Carmaux',
#  'Gare de Tessonnières',
#  'Gare de Pamiers',
#  'Gare de Montauban-Ville-Bourbon',
#  'Gare de St-Sulpice (Tarn)',
#  'Gare de Tarbes',
#  'Gare de St-Germain-des-Fossés',
#  'Gare de Lunel',
#  'Gare de Béziers',
#  'Gare de Génolhac',
#  'Gare de Avignon-TGV',
#  'Gare de Cavaillon',
#  'Gare de Gardanne',
#  'Gare de Manosque-Gréoux',
#  'Gare de Aubagne',
#  'Gare de Antibes',
#  'Gare de Hyères',
#  'Gare de Carnoules',
#  'Gare de Grenoble U.-Gières',
#  'Gare de St-Marcellin',
#  'Gare de Givors-Ville',
#  'Gare de Roanne',
#  'Gare de Vienne',
#  'Gare de Bas-Monistrol',
#  'Gare de Lyon-St-Paul',
#  "Gare de L'Arbresle",
#  'Gare de Brignais',
#  'Gare de Montereau',
#  'Gare de Corbigny',
#  'Gare de Chalon-sur-Saône',
#  'Gare de Is-sur-Tille',
#  'Gare de Etang',
#  'Gare de Montchanin',
#  'Gare de Trouville-Deauville',
#  'Gare de Paris-Montp.3-Vaug.',
#  'Gare de Paris-Montparnasse 1-2',
#  'Gare de Villefranche-Vernet-l.B',
#  'Gare de Valence-Ville',
#  'Gare de Sens',
#  'Gare de Morteau',
#  'Gare de Vallorbe-Cff',
#  'Gare de Travers',
#  'Gare de Meroux',
#  'Gare de Vallorcine',
#  'Gare de Mons',
#  'Gare de Namur',
#  'Gare de Tournai',
#  'Gare de Tende',
#  'Gare de Wissembourg',
#  'Haguenau-Moulin-Neuf.',
#  'Niedermodern/Uberach',
#  'Saverne-(Ht-Barr)',
#  'Neuwiller-R.-Bouxwiller',
#  'Pfaffenhoffen-(Mairie).',
#  'Gare de Raedersheim',
#  'Gare de Wingen-sur-Moder',
#  'Reipertswiller-SP.',
#  'Lichtenberg-(Eglise).',
#  'Thann Arrêt La Poste',
#  'Gare de Thann',
#  'Gare de Wesserling',
#  'Gare de Metzeral',
#  'Sewen-(Eglise)',
#  'Saverne-(Lycée-Verne)',
#  'Saverne-(Pl.-Dragons)',
#  'Gare de Montreux-Vieux',
#  'Ribeauville-Gare-Routiè',
#  'Riquewihr-Poste',
#  'Ste-Marie/-Ms-(-Théâtre',
#  'Sèlestat-(Schwilgué)',
#  'Sélestat-(Schweisguth)',
#  'Lièpvre-(Rte-Vancelle)',
#  'Le-Mont-Dore-Gare',
#  'Gare de St-Denis-près-Martel',
#  'Gare de Vichy',
#  "Urcay-Hotel-du-Lyon-d'O",
#  'Gare de St-Amand-Montrond-Orval',
#  'Gare de Vertaizon',
#  'St-Eloy',
#  'St-Eloy-les-Mines-Lycée',
#  'St-Gervais-Mairie',
#  'Le Mont Dore Ski',
#  'St-Flour-les-Allées',
#  'Mauriac-Lycée-Cortat',
#  'Mauriac',
#  'St-Gervais-Ch-LPA.',
#  'Riom_Es_M_la_Poste.',
#  'Gare de St-Flour-Chaudes-Aigues',
#  'Pontgibaud-Ville',
#  "Gare de St-Georges-d'Aurac",
#  "St-George-d'Aurac-Bourg",
#  'La Chaise-Dieu',
#  'Issoire-Lycée-Deville',
#  'Le-Breuil-sur-Couze-Lyc',
#  'Gare de St-Pierre-le-Moûtier',
#  'Gare de Paray-le-Monial',
#  'Gare de Seurre',
#  'Gare de Quimperlé',
#  'Gare de Retiers',
#  'Luçay-le-Male',
#  'Sedan-Place-Calonne',
#  'Gare de Verdun',
#  'Gare de Vitry-le-François',
#  'Langres-Gendarmerie',
#  'Juvancourt',
#  'Ville-sous-La-Ferté',
#  'Payns Abri Savières',
#  'Gare de Lure',
#  'Gare de Poligny',
#  'Les Granges-Narboz',
#  'Jougne',
#  'Marvejols Place Chayla',
#  'Quillan',
#  'Gare de Meymac',
#  'Mirecourt',
#  'Vézelise Beauregard',
#  'Mirecourt (Lycée Agric)',
#  'Gare de Montmédy',
#  'Vezin-Carrefour',
#  'Gare de Rémilly',
#  'St-Jean-de-Bassel-Eglis',
#  'Sarrebourg-Hôpital',
#  'Neufchateau-Lp',
#  'Laveline-d-Bruy. Mairie',
#  'Kédange (Eglise)',
#  'Hombourg (Chapelle)',
#  'Saint-Léonard Centre',
#  'Perl Gare DB',
#  'Sarre-Union',
#  'Sarralbe Centre',
#  'Sarrebourg-Abri-Phalsbo',
#  'Sarralbe',
#  'Gare de Revigny',
#  'Gare de Pagny-sur-Moselle',
#  'Gare de Gramat',
#  'Gare de Toulouse-Matabiau',
#  'Gare de Castelsarrasin',
#  'St-Sulpice-sur-Lèze',
#  'Luchon-Richelieu',
#  'Luchon',
#  'Latour de Carol',
#  'Wambrechies',
#  'Gare de Rue',
#  'Gare de Hirson-Ecoles',
#  'Gare de Lison',
#  'Gare de Pontorson-Mt-St-Michel',
#  'Vire-Centre',
#  'Gare de Flers',
#  'Gare de Briouze',
#  'Gare de Surdon',
#  'Normandie',
#  'Le Mont St Michel',
#  'Routot-Place-de-mairie',
#  'Gare de St-Gilles-Croix-de-Vie',
#  'Laon-Gare-Routière-Poma',
#  'Gare de Ribécourt',
#  'Gare de Prissé-la-Charrière',
#  'Valence-Gare-Routière',
#  'Gare de Lyon-Gorge-de-Loup',
#  'Lyon-St-Paul-Quai-Bondy',
#  'Grandris-Centre',
#  'Poule-Mairie',
#  'Morez Lycée',
#  "St-Martin-d'Hères",
#  'Gare de Pont-de-Beauvoisin',
#  'Gare de St-Brieuc',
#  'Gare de Lamballe',
#  'Gare de St-Vit',
#  'Gare de Villers-les-Pots',
#  'Gare de Neuilly-lès-Dijon',
#  'Gare de St-Rambert-en-Bugey',
#  'Gare de Virieu-le-Grand-Belley',
#  'Gare de Mâcon-Loché-TGV',
#  'Lyon-St-Paul-la-Feuilée',
#  'Vienne-Gare-Routière',
#  "Gare de St-Pierre-d'Albigny",
#  'St-Pierre-de-Chandieu-R',
#  'Gare de Rives',
#  'Gare de Culoz',
#  'Gare de Rumilly',
#  'Ternay-Barbières',
#  'Gare de Montmélian',
#  'St Christophe / Nais C.',
#  'Gare de Courtalain-St-Pellerin',
#  'Mondoubleau-Rue-Leroy',
#  'Montargis-OT',
#  'Sancerre-Porte-Cesar',
#  'nan',
#  'Issoudun-Place-de-la-G.',
#  'Issoudun-Jardin',
#  'Poitiers-Gare-Routière',
#  'Romorantin-Lycée-de-F',
#  'Gare de Eguzon',
#  'St-Aignan-Lep',
#  'St-Aignan-Pl-Wilson',
#  'Châteauroux-Charmilles',
#  'Gare de Montbazon',
#  'Truyes-St-Blaise',
#  'TOURS LYCEE GRANDMONT',
#  'Reignac-Bourg-Du-Fau',
#  'Truyes-Pl-Du-Souvenir',
#  'Gare de Veigné',
#  'Châteauroux-L-Giraudoux',
#  'Vierzon-Médiathèque',
#  'Gare de Limeray',
#  'Gare de Dourdan',
#  'Gare de Vendôme-Villiers-s-Loir',
#  'Rambervillers (11 Nov)',
#  'Moyen',
#  'Rambervillers',
#  'Gérardmer La Mauselaine',
#  'La-Bresse (Pl Champtel)',
#  'La Bresse Le Lispach',
#  'St-Louis-57-Incliné',
#  'Lugny',
#  'Gare de Verneuil-sur-Serre',
#  'Gare de WOERTH RHEIN',
#  'Gare de Ventimiglia-Stazione',
#  'Gare de Trier-Hbf (Trèves)',
#  'Gare de Rodange',
#  'Gare de Mullheim-Baden-Bf',
#  'Gare de Munster',
#  'Mutzig-Passage-A-Niveau',
#  'Gare de Puyoô',
#  'Gare de Morcenx',
#  'Gare de Pauillac',
#  'Gare de Le-Verdon',
#  'Gare de St-Jean-Pied-de-Port',
#  'Gare de Cambo-les-Bains',
#  'Gare de Hendaye',
#  'Gare de St-Emilion',
#  'Gare de Sarlat',
#  'Gare de Langon',
#  'Gare de Vorey',
#  'Gare de Tonnerre',
#  'Gare de Les Laumes-Alésia',
#  'Gare de Nevers-Le-Banlay',
#  'Gare de Vesoul',
#  'Gare de Vitré',
#  'Gare de Vannes',
#  'Gare de Rosporden',
#  'Gare de Morlaix',
#  'Gare de La Forest',
#  'Gare de Toury',
#  'Gare de Château-Gaillard',
#  'Gare de La Verrière',
#  'Gare de Versailles-Chantiers',
#  'Gare de Givet',
#  'Gare de Nouzonville',
#  'Gare de Sedan',
#  'Gare de Vauvert',
#  'Gare de Saillat-Chassenon',
#  'Pompadour',
#  'Gare de Pont-St-Vincent',
#  'Laissac-Foirail',
#  'Gare de Rang du Fl. Verton Ber.',
#  'Gare de Mouscron / Moeskroen',
#  'Gare de Valenciennes',
#  'Gare de St Pol sur Ternoise',
#  'Gare de Sablé-sur-Sarthe',
#  'Gare de Persan-Beaumont',
#  'Gare de St-Just-SNCF',
#  'Le Tréport-Mers-Les-B',
#  'Gare de Saintes',
#  'Gare de Rochefort',
#  'Gare de St-Mariens-St-Yzan',
#  'Gare de Toulon',
#  'Gare de St-Raphaël-Valescure',
#  'Gare de Sospel',
#  "Gare de Touet-de-l'Escarène",
#  'Gare de Miramas',
#  'Gare de Sisteron',
#  'Gare de Martigues',
#  'Gare de Willer-sur-Thur',
#  'Gare de Etaples Le Touquet',
#  'Gare de Tourcoing',
#  'Gare de St Omer',
#  'Gare de Vernon-Giverny',
#  'Gare de Montivilliers',
#  'Gare de Rolleville',
#  'Gare de Yvetot',
#  'Gare de Serquigny',
#  'Gare de St-Lô',
#  'Gare de St-Malo',
#  'Gare de Plouaret-Trégor',
#  'Gare de Paimpol',
#  'Gare de St-Nazaire',
#  'Gare de Savenay',
#  'Gare de Ste-Pazanne',
#  'Gare de Pornic',
#  'Gare de Sucé-Sur-Erdre',
#  'Gare de Nort-sur-Erdre',
#  'Gare de Voves',
#  'Gare de Vallon-en-Sully',
#  'Gare de Coutras',
#  'Gare de Pessac',
#  'Gare de Marmande',
#  'Gare de St-Junien',
#  'Gare de Saint-Cyprien-Arènes',
#  'Gare de Durtol-Nohanent',
#  'Gare de Le Lioran',
#  'Gare de Sète',
#  'Gare de Orange',
#  'Gare de Carpentras',
#  'Gare de Marseille-Blancarde',
#  'Gare de Pierrelatte',
#  'Gare de St-Etienne-Châteaucreux',
#  'Gare de Sathonay-Rillieux',
#  'Gare de Tassin',
#  'Gare de Montbéliard-Ville']

# %%
# get all possible itineraries from un localisation
def get_itineraries(fromLoc):
    return itineraries.loc[itineraries['start'] == fromLoc]

# %%
# update distance of localisation from source
def updateDistanceFromSource(matrix, itineraries):
    # print(itineraries)
    
    for index, row in itineraries.iterrows():
        
        # if initerary is not yet processed
        if matrix[row['end']]['processed'] == False:
        
            oldValue = matrix[row['end']]['distanceFromSource']
            newValue = matrix[row['start']]['distanceFromSource'] + row['duree']
            
            if oldValue == 'infinite':
                matrix[row['end']]['distanceFromSource'] = newValue
                matrix[row['end']]['fromLoc'] = row['start']
            else:   
                if newValue < oldValue:
                    matrix[row['end']]['distanceFromSource'] = newValue
                    matrix[row['end']]['fromLoc'] = row['start']
        
        
    print("-----------------------------------------------------------------")
    print("---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------")
    print("-----------------------------------------------------------------")
    print(" ")
    
    return matrix

# %%
# Find the minimum distance that has not been processed and that is not infinite
def findMiniDistanceFromSource(matrix):
    
    toProcess = {}
    
    for index, row in matrix.items():
        if row['processed'] == False and row['distanceFromSource'] != 'infinite':
            toProcess[index] = row
            
    print("-------------------- Les itineraires pas encore traités ---------------------")
    print(" ")
    [print(key,':',value) for key, value in toProcess.items()]
    print(" ")
    
    miniValue = 9999999999
    location = ""
    
    for index, row in toProcess.items():
    
        if row['distanceFromSource'] < miniValue:
            miniValue = row['distanceFromSource']
            location = index
            
       
    if location != "":    
        print("-------------------- La distance la plus courte pas encore traitée ---------------------")
        print(" ")
        print("Etape : ", location, " - Distance depuis la source : ", miniValue)
        print(" ")
    else:
        print("------------------------------------------------------------------------")
        print("-------------------- Plus de trajets lié à traiter ---------------------")
        print("------------------------------------------------------------------------")
        print(" ")
        
    return location

# %%
# find the shortest distance between source and destination 
def get_best_itinerary(matrix, source, destination):
    toProcess = {}
    distance = ""
    fromLoc = ""
    itineraries = []
    
    for index, row in matrix.items():
        if row['processed'] == True and row['distanceFromSource'] != 'infinite':
            toProcess[index] = row
            
    # print(toProcess)
    if destination in toProcess.keys():
        print(toProcess[destination])
        distance = toProcess[destination]["distanceFromSource"]
        fromLoc = toProcess[destination]["fromLoc"]
        itineraries.insert(0, destination)
        
        while fromLoc != source:
            itineraries.insert(0, fromLoc)
            fromLoc = toProcess[fromLoc]["fromLoc"]
            
        itineraries.insert(0, source)
        
        return {
            'itineraries': itineraries,
            'distance': distance
        }
    
    else:
        print("-----------------------------------------------------------------")
        print("-------------------- Ce trajet n'existe pas ---------------------")
        print("-----------------------------------------------------------------")
        print("")
        
        return "None"

# %%
# Find the shortest path among all possible sources and destinations 
def dijsktra(df, source, destination):
    matrixLoc = {}
    
    locsStart = df['start'].tolist()
    locsEnd = df['end'].tolist()
    locs = list(dict.fromkeys(locsStart + locsEnd))
    
    # filter possible localisations
    locsStart = list(filter(lambda k: source in k, locs))
    locsEnd = list(filter(lambda k: destination in k, locs))
    
    # print(locsStart)
    # print(locsEnd)
    
    returnResult = "None"

    for locStart in locsStart:
        matrixLoc = {}
        
        for locEnd in locsEnd:
            if locEnd == locStart:
                continue
            
            matrixLoc = {}
    
            print("Trajet : ", locStart, " - ", locEnd)
            print(" ")
            
            # initialize matrix
            for loc in locs:
                matrixLoc[loc] = {
                    'distanceFromSource': 'infinite',
                    'fromLoc': '',
                    'processed': False,
                }
                
            # initialize matrix source values
            matrixLoc[locStart]['distanceFromSource'] = 0
            matrixLoc[locStart]['fromLoc'] = locStart
            matrixLoc[locStart]['processed'] = True
            
            nextLocation = locStart
            
            while nextLocation != "":

                if not get_itineraries(nextLocation).empty:
                    matrixLoc = updateDistanceFromSource(matrixLoc, get_itineraries(nextLocation))
                else:
                    print("Aucun itinéraire en partant de ", nextLocation)
                    print(" ")
                    
                nextLocation = findMiniDistanceFromSource(matrixLoc)

                if nextLocation != "":
                    matrixLoc[nextLocation]['processed'] = True
            
            result = get_best_itinerary(matrixLoc, locStart, locEnd)
            
            if result != "None":
                return result

    return "None"

# %%
def get_itinerary(df, source, destination):
    result = dijsktra(df, source, destination)

    if result == "None":
        result = dijsktra(df, destination, source)

    if result != "None":
        itineraries = result['itineraries']
        itineraries.reverse()
        result['itineraries'] = itineraries
        return result
    
    else:
        print("-----------------------------------------------------------------")
        print("---------------------- Aucun trajet trouvé ----------------------")
        print("-----------------------------------------------------------------")
        print("")
        return

# %%
locStart = "Paris"
locEnd = "Bordeaux"

get_itinerary(itineraries, locStart, locEnd)
# Out:
# Trajet :  Gare de Paris-St-Lazare  -  Gare de Bordeaux-St-Jean
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Rouen-Rive-Droite : {'distanceFromSource': 97, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Trouville-Deauville : {'distanceFromSource': 147, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Vernon-Giverny : {'distanceFromSource': 60, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Serquigny : {'distanceFromSource': 105, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vernon-Giverny  - Distance depuis la source :  60
#
# Aucun itinéraire en partant de  Gare de Vernon-Giverny
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Rouen-Rive-Droite : {'distanceFromSource': 97, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Trouville-Deauville : {'distanceFromSource': 147, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Serquigny : {'distanceFromSource': 105, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Rouen-Rive-Droite  - Distance depuis la source :  97
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Trouville-Deauville : {'distanceFromSource': 147, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Yvetot : {'distanceFromSource': 131, 'fromLoc': 'Gare de Rouen-Rive-Droite', 'processed': False}
# Gare de Serquigny : {'distanceFromSource': 105, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Serquigny  - Distance depuis la source :  105
#
# Aucun itinéraire en partant de  Gare de Serquigny
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Trouville-Deauville : {'distanceFromSource': 147, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
# Gare de Yvetot : {'distanceFromSource': 131, 'fromLoc': 'Gare de Rouen-Rive-Droite', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Yvetot  - Distance depuis la source :  131
#
# Aucun itinéraire en partant de  Gare de Yvetot
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Trouville-Deauville : {'distanceFromSource': 147, 'fromLoc': 'Gare de Paris-St-Lazare', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Trouville-Deauville  - Distance depuis la source :  147
#
# Aucun itinéraire en partant de  Gare de Trouville-Deauville
#
# -------------------- Les itineraires pas encore traités ---------------------
#
#
# ------------------------------------------------------------------------
# -------------------- Plus de trajets lié à traiter ---------------------
# ------------------------------------------------------------------------
#
# -----------------------------------------------------------------
# -------------------- Ce trajet n'existe pas ---------------------
# -----------------------------------------------------------------
#
# Trajet :  Gare de Paris-Austerlitz  -  Gare de Bordeaux-St-Jean
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tours : {'distanceFromSource': 131, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 139, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Gare de Vierzon : {'distanceFromSource': 101, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 118, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vierzon  - Distance depuis la source :  101
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tours : {'distanceFromSource': 131, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 139, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Romorantin-BA-G.R. : {'distanceFromSource': 144, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 118, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 151, 'fromLoc': 'Gare de Vierzon', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de St-Pierre-des-Corps  - Distance depuis la source :  118
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tours : {'distanceFromSource': 123, 'fromLoc': 'Gare de St-Pierre-des-Corps', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 139, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Romorantin-BA-G.R. : {'distanceFromSource': 144, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 151, 'fromLoc': 'Gare de Vierzon', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Tours  - Distance depuis la source :  123
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vendôme : {'distanceFromSource': 139, 'fromLoc': 'Gare de Paris-Austerlitz', 'processed': False}
# Romorantin-BA-G.R. : {'distanceFromSource': 144, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 183, 'fromLoc': 'Gare de Tours', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 151, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vendôme  - Distance depuis la source :  139
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Romorantin-BA-G.R. : {'distanceFromSource': 144, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 183, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 151, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Romorantin-BA-G.R.  - Distance depuis la source :  144
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 183, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 151, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 197, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 192, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Issoudun-Place-de-la-G.  - Distance depuis la source :  151
#
# Aucun itinéraire en partant de  Issoudun-Place-de-la-G.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 183, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 197, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 192, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St Christophe / Nais C.  - Distance depuis la source :  183
#
# Aucun itinéraire en partant de  St Christophe / Nais C.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 197, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 192, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Vierzon-Médiathèque  - Distance depuis la source :  192
#
# Aucun itinéraire en partant de  Vierzon-Médiathèque
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 197, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Aignan-Pl-Wilson  - Distance depuis la source :  197
#
# Aucun itinéraire en partant de  St-Aignan-Pl-Wilson
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 197, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Reignac-Bourg-Du-Fau  - Distance depuis la source :  197
#
# Aucun itinéraire en partant de  Reignac-Bourg-Du-Fau
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 199, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Mondoubleau-Rue-Leroy  - Distance depuis la source :  199
#
# Aucun itinéraire en partant de  Mondoubleau-Rue-Leroy
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 199, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Aignan-Lep  - Distance depuis la source :  199
#
# Aucun itinéraire en partant de  St-Aignan-Lep
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Loches-LEP : {'distanceFromSource': 203, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Loches-LEP  - Distance depuis la source :  203
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 228, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Truyes-Pl-Du-Souvenir  - Distance depuis la source :  228
#
# Aucun itinéraire en partant de  Truyes-Pl-Du-Souvenir
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Voves : {'distanceFromSource': 260, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Voves  - Distance depuis la source :  260
#
# Aucun itinéraire en partant de  Gare de Voves
#
# -------------------- Les itineraires pas encore traités ---------------------
#
#
# ------------------------------------------------------------------------
# -------------------- Plus de trajets lié à traiter ---------------------
# ------------------------------------------------------------------------
#
# -----------------------------------------------------------------
# -------------------- Ce trajet n'existe pas ---------------------
# -----------------------------------------------------------------
#
# Trajet :  Gare de Paris-Bercy  -  Gare de Bordeaux-St-Jean
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tours : {'distanceFromSource': 146, 'fromLoc': 'Gare de Paris-Bercy', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 149, 'fromLoc': 'Gare de Paris-Bercy', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Tours  - Distance depuis la source :  146
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vendôme : {'distanceFromSource': 149, 'fromLoc': 'Gare de Paris-Bercy', 'processed': False}
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 226, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 206, 'fromLoc': 'Gare de Tours', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 220, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vendôme  - Distance depuis la source :  149
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 226, 'fromLoc': 'Gare de Tours', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 206, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 209, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 220, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St Christophe / Nais C.  - Distance depuis la source :  206
#
# Aucun itinéraire en partant de  St Christophe / Nais C.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 226, 'fromLoc': 'Gare de Tours', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 209, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 220, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Mondoubleau-Rue-Leroy  - Distance depuis la source :  209
#
# Aucun itinéraire en partant de  Mondoubleau-Rue-Leroy
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 226, 'fromLoc': 'Gare de Tours', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 220, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Reignac-Bourg-Du-Fau  - Distance depuis la source :  220
#
# Aucun itinéraire en partant de  Reignac-Bourg-Du-Fau
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 226, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Loches-LEP  - Distance depuis la source :  226
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Vierzon : {'distanceFromSource': 233, 'fromLoc': 'Gare de Tours', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 251, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vierzon  - Distance depuis la source :  233
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Romorantin-BA-G.R. : {'distanceFromSource': 276, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 283, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 251, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Truyes-Pl-Du-Souvenir  - Distance depuis la source :  251
#
# Aucun itinéraire en partant de  Truyes-Pl-Du-Souvenir
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Romorantin-BA-G.R. : {'distanceFromSource': 276, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Issoudun-Place-de-la-G. : {'distanceFromSource': 283, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Romorantin-BA-G.R.  - Distance depuis la source :  276
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Issoudun-Place-de-la-G. : {'distanceFromSource': 283, 'fromLoc': 'Gare de Vierzon', 'processed': False}
# St-Aignan-Lep : {'distanceFromSource': 331, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 329, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 324, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Issoudun-Place-de-la-G.  - Distance depuis la source :  283
#
# Aucun itinéraire en partant de  Issoudun-Place-de-la-G.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# St-Aignan-Lep : {'distanceFromSource': 331, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 329, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 324, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Gare de Voves : {'distanceFromSource': 283, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Voves  - Distance depuis la source :  283
#
# Aucun itinéraire en partant de  Gare de Voves
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# St-Aignan-Lep : {'distanceFromSource': 331, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 329, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# Vierzon-Médiathèque : {'distanceFromSource': 324, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Vierzon-Médiathèque  - Distance depuis la source :  324
#
# Aucun itinéraire en partant de  Vierzon-Médiathèque
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# St-Aignan-Lep : {'distanceFromSource': 331, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
# St-Aignan-Pl-Wilson : {'distanceFromSource': 329, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Aignan-Pl-Wilson  - Distance depuis la source :  329
#
# Aucun itinéraire en partant de  St-Aignan-Pl-Wilson
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# St-Aignan-Lep : {'distanceFromSource': 331, 'fromLoc': 'Romorantin-BA-G.R.', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Aignan-Lep  - Distance depuis la source :  331
#
# Aucun itinéraire en partant de  St-Aignan-Lep
#
# -------------------- Les itineraires pas encore traités ---------------------
#
#
# ------------------------------------------------------------------------
# -------------------- Plus de trajets lié à traiter ---------------------
# ------------------------------------------------------------------------
#
# -----------------------------------------------------------------
# -------------------- Ce trajet n'existe pas ---------------------
# -----------------------------------------------------------------
#
# Trajet :  Gare de Paris Gare du Nord  -  Gare de Bordeaux-St-Jean
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tergnier : {'distanceFromSource': 88, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de St Quentin : {'distanceFromSource': 100, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de Persan-Beaumont : {'distanceFromSource': 63, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de St-Just-SNCF : {'distanceFromSource': 64, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Persan-Beaumont  - Distance depuis la source :  63
#
# Aucun itinéraire en partant de  Gare de Persan-Beaumont
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tergnier : {'distanceFromSource': 88, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de St Quentin : {'distanceFromSource': 100, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de St-Just-SNCF : {'distanceFromSource': 64, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de St-Just-SNCF  - Distance depuis la source :  64
#
# Aucun itinéraire en partant de  Gare de St-Just-SNCF
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tergnier : {'distanceFromSource': 88, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Gare de St Quentin : {'distanceFromSource': 100, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Tergnier  - Distance depuis la source :  88
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de St Quentin : {'distanceFromSource': 100, 'fromLoc': 'Gare de Paris Gare du Nord', 'processed': False}
# Laon-Gare-Routière-Poma : {'distanceFromSource': 155, 'fromLoc': 'Gare de Tergnier', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de St Quentin  - Distance depuis la source :  100
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Laon-Gare-Routière-Poma : {'distanceFromSource': 155, 'fromLoc': 'Gare de Tergnier', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Laon-Gare-Routière-Poma  - Distance depuis la source :  155
#
# Aucun itinéraire en partant de  Laon-Gare-Routière-Poma
#
# -------------------- Les itineraires pas encore traités ---------------------
#
#
# ------------------------------------------------------------------------
# -------------------- Plus de trajets lié à traiter ---------------------
# ------------------------------------------------------------------------
#
# -----------------------------------------------------------------
# -------------------- Ce trajet n'existe pas ---------------------
# -----------------------------------------------------------------
#
# Trajet :  Gare de Paris-Est  -  Gare de Bordeaux-St-Jean
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de St-Dizier : {'distanceFromSource': 140, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Troyes : {'distanceFromSource': 90, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Troyes  - Distance depuis la source :  90
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de St-Dizier : {'distanceFromSource': 140, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vendeuvre (Aube) : {'distanceFromSource': 145, 'fromLoc': 'Gare de Troyes', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Payns Abri Savières : {'distanceFromSource': 116, 'fromLoc': 'Gare de Troyes', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Payns Abri Savières  - Distance depuis la source :  116
#
# Aucun itinéraire en partant de  Payns Abri Savières
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de St-Dizier : {'distanceFromSource': 140, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vendeuvre (Aube) : {'distanceFromSource': 145, 'fromLoc': 'Gare de Troyes', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de St-Dizier  - Distance depuis la source :  140
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vendeuvre (Aube) : {'distanceFromSource': 145, 'fromLoc': 'Gare de Troyes', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vitry-le-François : {'distanceFromSource': 191, 'fromLoc': 'Gare de St-Dizier', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vendeuvre (Aube)  - Distance depuis la source :  145
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vitry-le-François : {'distanceFromSource': 191, 'fromLoc': 'Gare de St-Dizier', 'processed': False}
# Juvancourt : {'distanceFromSource': 230, 'fromLoc': 'Gare de Vendeuvre (Aube)', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vitry-le-François  - Distance depuis la source :  191
#
# Aucun itinéraire en partant de  Gare de Vitry-le-François
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Vittel : {'distanceFromSource': 230, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Juvancourt : {'distanceFromSource': 230, 'fromLoc': 'Gare de Vendeuvre (Aube)', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vittel  - Distance depuis la source :  230
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Juvancourt : {'distanceFromSource': 230, 'fromLoc': 'Gare de Vendeuvre (Aube)', 'processed': False}
# Mirecourt : {'distanceFromSource': 256, 'fromLoc': 'Gare de Vittel', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Juvancourt  - Distance depuis la source :  230
#
# Aucun itinéraire en partant de  Juvancourt
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Mirecourt : {'distanceFromSource': 256, 'fromLoc': 'Gare de Vittel', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Mirecourt  - Distance depuis la source :  256
#
# Aucun itinéraire en partant de  Mirecourt
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 359, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
# Gare de Sarrebourg : {'distanceFromSource': 270, 'fromLoc': 'Gare de Paris-Est', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Sarrebourg  - Distance depuis la source :  270
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 329, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Igney (Centre) : {'distanceFromSource': 309, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Loudrefing : {'distanceFromSource': 304, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# St-Jean-de-Bassel-Eglis : {'distanceFromSource': 305, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# St-Louis-57-Incliné : {'distanceFromSource': 297, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Louis-57-Incliné  - Distance depuis la source :  297
#
# Aucun itinéraire en partant de  St-Louis-57-Incliné
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 329, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Igney (Centre) : {'distanceFromSource': 309, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Loudrefing : {'distanceFromSource': 304, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# St-Jean-de-Bassel-Eglis : {'distanceFromSource': 305, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Loudrefing  - Distance depuis la source :  304
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 329, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Igney (Centre) : {'distanceFromSource': 309, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Sarrebourg (Place Math) : {'distanceFromSource': 354, 'fromLoc': 'Loudrefing', 'processed': False}
# Sarrebourg-LP-Messmer : {'distanceFromSource': 358, 'fromLoc': 'Loudrefing', 'processed': False}
# St-Jean-de-Bassel-Eglis : {'distanceFromSource': 305, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Jean-de-Bassel-Eglis  - Distance depuis la source :  305
#
# Aucun itinéraire en partant de  St-Jean-de-Bassel-Eglis
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 329, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Igney (Centre) : {'distanceFromSource': 309, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Sarrebourg (Place Math) : {'distanceFromSource': 354, 'fromLoc': 'Loudrefing', 'processed': False}
# Sarrebourg-LP-Messmer : {'distanceFromSource': 358, 'fromLoc': 'Loudrefing', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Igney (Centre)  - Distance depuis la source :  309
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Strasbourg : {'distanceFromSource': 329, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Sarrebourg (Place Math) : {'distanceFromSource': 354, 'fromLoc': 'Loudrefing', 'processed': False}
# Sarrebourg-LP-Messmer : {'distanceFromSource': 354, 'fromLoc': 'Igney (Centre)', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Strasbourg  - Distance depuis la source :  329
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sélestat : {'distanceFromSource': 382, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Sarrebourg (Place Math) : {'distanceFromSource': 354, 'fromLoc': 'Loudrefing', 'processed': False}
# Sarrebourg-LP-Messmer : {'distanceFromSource': 354, 'fromLoc': 'Igney (Centre)', 'processed': False}
# Gare de Wissembourg : {'distanceFromSource': 387, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wingen-sur-Moder : {'distanceFromSource': 393, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de WOERTH RHEIN : {'distanceFromSource': 395, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Sarrebourg (Place Math)  - Distance depuis la source :  354
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sélestat : {'distanceFromSource': 382, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Sarrebourg-LP-Messmer : {'distanceFromSource': 354, 'fromLoc': 'Igney (Centre)', 'processed': False}
# Gare de Wissembourg : {'distanceFromSource': 387, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wingen-sur-Moder : {'distanceFromSource': 393, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de WOERTH RHEIN : {'distanceFromSource': 395, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Sarrebourg-LP-Messmer  - Distance depuis la source :  354
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Sarreguemines : {'distanceFromSource': 355, 'fromLoc': 'Gare de Sarrebourg', 'processed': False}
# Gare de Sélestat : {'distanceFromSource': 382, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wissembourg : {'distanceFromSource': 387, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wingen-sur-Moder : {'distanceFromSource': 393, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de WOERTH RHEIN : {'distanceFromSource': 395, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Sarreguemines  - Distance depuis la source :  355
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Sélestat : {'distanceFromSource': 382, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wissembourg : {'distanceFromSource': 387, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Gare de Wingen-sur-Moder : {'distanceFromSource': 393, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
# Sarre-Union : {'distanceFromSource': 407, 'fromLoc': 'Gare de Sarreguemines', 'processed': False}
# Sarralbe Centre : {'distanceFromSource': 388, 'fromLoc': 'Gare de Sarreguemines', 'processed': False}
# Gare de WOERTH RHEIN : {'distanceFromSource': 395, 'fromLoc': 'Gare de Strasbourg', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Sélestat  - Distance depuis la source :  382
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# ...
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 401, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 406, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# St-Flour-les-Allées : {'distanceFromSource': 397, 'fromLoc': "Gare de St-Chély-d'Apcher", 'processed': False}
# Riom_Es_M_la_Poste. : {'distanceFromSource': 380, 'fromLoc': 'Gare de Neussargues', 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 396, 'fromLoc': 'Gare de Tours', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Riom_Es_M_la_Poste.  - Distance depuis la source :  380
#
# Aucun itinéraire en partant de  Riom_Es_M_la_Poste.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 401, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 406, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# St-Flour-les-Allées : {'distanceFromSource': 397, 'fromLoc': "Gare de St-Chély-d'Apcher", 'processed': False}
# St Christophe / Nais C. : {'distanceFromSource': 396, 'fromLoc': 'Gare de Tours', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St Christophe / Nais C.  - Distance depuis la source :  396
#
# Aucun itinéraire en partant de  St Christophe / Nais C.
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 401, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 406, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# St-Flour-les-Allées : {'distanceFromSource': 397, 'fromLoc': "Gare de St-Chély-d'Apcher", 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  St-Flour-les-Allées  - Distance depuis la source :  397
#
# Aucun itinéraire en partant de  St-Flour-les-Allées
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Gare de Vendôme : {'distanceFromSource': 401, 'fromLoc': 'Gare de Tours', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 406, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vendôme  - Distance depuis la source :  401
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de St-Pierre-des-Corps : {'distanceFromSource': 406, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de St-Pierre-des-Corps  - Distance depuis la source :  406
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Reignac-Bourg-Du-Fau : {'distanceFromSource': 410, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Reignac-Bourg-Du-Fau  - Distance depuis la source :  410
#
# Aucun itinéraire en partant de  Reignac-Bourg-Du-Fau
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Loches-LEP : {'distanceFromSource': 416, 'fromLoc': 'Gare de Tours', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Loches-LEP  - Distance depuis la source :  416
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Vic-le-Comte : {'distanceFromSource': 417, 'fromLoc': 'Gare de Riom-Châtel-Guyon', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 441, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Vic-le-Comte  - Distance depuis la source :  417
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Austerlitz : {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Issoire-Lycée-Deville : {'distanceFromSource': 447, 'fromLoc': 'Gare de Vic-le-Comte', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 441, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Paris-Austerlitz  - Distance depuis la source :  423
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Paris-Bercy : {'distanceFromSource': 432, 'fromLoc': 'Gare de Orléans', 'processed': False}
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Issoire-Lycée-Deville : {'distanceFromSource': 447, 'fromLoc': 'Gare de Vic-le-Comte', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 441, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Paris-Bercy  - Distance depuis la source :  432
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Issoire-Lycée-Deville : {'distanceFromSource': 447, 'fromLoc': 'Gare de Vic-le-Comte', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Truyes-Pl-Du-Souvenir : {'distanceFromSource': 441, 'fromLoc': 'Loches-LEP', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Truyes-Pl-Du-Souvenir  - Distance depuis la source :  441
#
# Aucun itinéraire en partant de  Truyes-Pl-Du-Souvenir
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Issoire-Lycée-Deville : {'distanceFromSource': 447, 'fromLoc': 'Gare de Vic-le-Comte', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Issoire-Lycée-Deville  - Distance depuis la source :  447
#
# Aucun itinéraire en partant de  Issoire-Lycée-Deville
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Mondoubleau-Rue-Leroy : {'distanceFromSource': 461, 'fromLoc': 'Gare de Vendôme', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Mondoubleau-Rue-Leroy  - Distance depuis la source :  461
#
# Aucun itinéraire en partant de  Mondoubleau-Rue-Leroy
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Tessonnières : {'distanceFromSource': 471, 'fromLoc': 'Gare de Figeac', 'processed': False}
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Tessonnières  - Distance depuis la source :  471
#
# -----------------------------------------------------------------
# ---------- MISE A JOUR DES DISTANCES DEPUIS LA SOURCE -----------
# -----------------------------------------------------------------
#
# -------------------- Les itineraires pas encore traités ---------------------
#
# Gare de Voves : {'distanceFromSource': 473, 'fromLoc': 'Gare de Tours', 'processed': False}
#
# -------------------- La distance la plus courte pas encore traitée ---------------------
#
# Etape :  Gare de Voves  - Distance depuis la source :  473
#
# Aucun itinéraire en partant de  Gare de Voves
#
# -------------------- Les itineraires pas encore traités ---------------------
#
#
# ------------------------------------------------------------------------
# -------------------- Plus de trajets lié à traiter ---------------------
# ------------------------------------------------------------------------
#
# {'distanceFromSource': 423, 'fromLoc': 'Gare de Orléans', 'processed': True}
# {'itineraries': ['Gare de Paris-Austerlitz',
#   'Gare de Orléans',
#   'Gare de Limoges-Bénédictins',
#   'Gare de Bordeaux-St-Jean'],
#  'distance': 423}
